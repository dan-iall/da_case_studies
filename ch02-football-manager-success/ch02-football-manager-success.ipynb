# %% [markdown]
# ### Chapter 02
# **CH02B Identifying successful football managers**
#
# using the football dataset
#
# version 0.9.0 2025-08-14

# %%
import os
import sys
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

warnings.filterwarnings("ignore")

# %%
# Current script folder
current_path = os.getcwd()
dirname = current_path.split("da_case_studies")[0]

# location folders
data_in = dirname + "da_data_repo/football/clean/"
data_out = dirname + "da_case_studies/ch02-football-manager-success/"
output = dirname + "da_case_studies/ch02-football-manager-success/output/"
func = dirname + "da_case_studies/ch00-tech-prep/"
sys.path.append(func)

# %%
# Import the prewritten helper functions
import py_helper_functions as da
sns.set_theme(rc=da.da_theme, palette=da.color)

# %%
epl_games = pd.read_csv(data_in + "epl_games.csv")

# %%
epl_games.sort_values(["team_home"])
# Out:
#      div  season       date team_home     team_away  points_home  points_away  \
# 0     E0    2008  16aug2008   Arsenal     West Brom            3            0
# 3638  E0    2017  03jan2018   Arsenal       Chelsea            1            1
# 1900  E0    2013  17aug2013   Arsenal   Aston Villa            0            3
# 1014  E0    2010  12feb2011   Arsenal        Wolves            3            0
# 3939  E0    2018  02dec2018   Arsenal     Tottenham            3            0
# ...   ..     ...        ...       ...           ...          ...          ...
# 1004  E0    2010  05feb2011    Wolves    Man United            3            0
# 489   E0    2009  07nov2009    Wolves       Arsenal            0            3
# 3928  E0    2018  25nov2018    Wolves  Huddersfield            0            3
# 553   E0    2009  20dec2009    Wolves       Burnley            3            0
# 1044  E0    2010  06mar2011    Wolves     Tottenham            1            1
#
#       goals_home  goals_away
# 0              1           0
# 3638           2           2
# 1900           1           3
# 1014           2           0
# 3939           4           2
# ...          ...         ...
# 1004           2           1
# 489            1           4
# 3928           0           2
# 553            2           0
# 1044           3           3
#
# [4180 rows x 9 columns]

# %%
epl_games.sort_values(["season", "team_home"])
# Out:
#      div  season       date team_home   team_away  points_home  points_away  \
# 0     E0    2008  16aug2008   Arsenal   West Brom            3            0
# 21    E0    2008  30aug2008   Arsenal   Newcastle            3            0
# 53    E0    2008  27sep2008   Arsenal        Hull            0            3
# 75    E0    2008  18oct2008   Arsenal     Everton            3            0
# 95    E0    2008  29oct2008   Arsenal   Tottenham            1            1
# ...   ..     ...        ...       ...         ...          ...          ...
# 4085  E0    2018  02mar2019    Wolves     Cardiff            3            0
# 4115  E0    2018  02apr2019    Wolves  Man United            3            0
# 4139  E0    2018  20apr2019    Wolves    Brighton            1            1
# 4148  E0    2018  24apr2019    Wolves     Arsenal            3            0
# 4164  E0    2018  04may2019    Wolves      Fulham            3            0
#
#       goals_home  goals_away
# 0              1           0
# 21             3           0
# 53             1           2
# 75             3           1
# 95             4           4
# ...          ...         ...
# 4085           2           0
# 4115           2           1
# 4139           0           0
# 4148           3           1
# 4164           1           0
#
# [4180 rows x 9 columns]

# %%
epl_games.loc[epl_games["season"] == 2016]
# Out:
#      div  season       date       team_home    team_away  points_home  \
# 3040  E0    2016  13aug2016   Middlesbrough        Stoke            1
# 3041  E0    2016  13aug2016         Burnley      Swansea            0
# 3042  E0    2016  13aug2016         Everton    Tottenham            1
# 3043  E0    2016  13aug2016  Crystal Palace    West Brom            0
# 3044  E0    2016  13aug2016        Man City   Sunderland            3
# ...   ..     ...        ...             ...          ...          ...
# 3415  E0    2016  21may2017         Swansea    West Brom            3
# 3416  E0    2016  21may2017         Chelsea   Sunderland            3
# 3417  E0    2016  21may2017         Arsenal      Everton            3
# 3418  E0    2016  21may2017         Watford     Man City            0
# 3419  E0    2016  21may2017       Leicester  Bournemouth            1
#
#       points_away  goals_home  goals_away
# 3040            1           1           1
# 3041            3           0           1
# 3042            1           1           1
# 3043            3           0           1
# 3044            0           2           1
# ...           ...         ...         ...
# 3415            0           2           1
# 3416            0           5           1
# 3417            0           3           1
# 3418            3           0           5
# 3419            1           1           1
#
# [380 rows x 9 columns]

# %%
# look at data for team-game level
epl_teams_games = pd.read_csv(data_in + "epl-teams-games.csv")

# %%
epl_teams_games.sort_values(["team"])
# Out:
#      div  season       date     team  gameno  home  points  goals  \
# 0     E0    2008  16aug2008  Arsenal       1     1       3      1
# 286   E0    2015  13jan2016  Arsenal      21     0       1      3
# 285   E0    2015  02jan2016  Arsenal      20     1       3      1
# 283   E0    2015  26dec2015  Arsenal      18     0       0      0
# 282   E0    2015  21dec2015  Arsenal      17     1       3      2
# ...   ..     ...        ...      ...     ...   ...     ...    ...
# 8259  E0    2010  20nov2010   Wolves      14     0       0      1
# 8260  E0    2010  27nov2010   Wolves      15     1       3      3
# 8261  E0    2010  04dec2010   Wolves      16     0       0      0
# 8254  E0    2010  23oct2010   Wolves       9     0       0      0
# 8359  E0    2018  12may2019   Wolves      38     0       0      0
#
#      team_opponent  points_opponent  goals_opponent  hometeam_uid  \
# 0        West Brom                0               0             1
# 286      Liverpool                1               3            18
# 285      Newcastle                0               0             1
# 283    Southampton                3               4            27
# 282       Man City                0               1             1
# ...            ...              ...             ...           ...
# 8259     Blackpool                3               2             5
# 8260    Sunderland                0               2            36
# 8261     Blackburn                3               3             4
# 8254       Chelsea                3               2            11
# 8359     Liverpool                3               2            18
#
#       awayteam_uid
# 0               33
# 286              1
# 285             22
# 283              1
# 282             19
# ...            ...
# 8259            36
# 8260            29
# 8261            36
# 8254            36
# 8359            36
#
# [8360 rows x 13 columns]

# %%
epl_teams_games.sort_values(["season", "team"])
# Out:
#      div  season       date     team  gameno  home  points  goals  \
# 0     E0    2008  16aug2008  Arsenal       1     1       3      1
# 1     E0    2008  23aug2008  Arsenal       2     0       0      0
# 2     E0    2008  30aug2008  Arsenal       3     1       3      3
# 3     E0    2008  13sep2008  Arsenal       4     0       3      4
# 4     E0    2008  20sep2008  Arsenal       5     0       3      3
# ...   ..     ...        ...      ...     ...   ...     ...    ...
# 8355  E0    2018  20apr2019   Wolves      34     1       1      0
# 8356  E0    2018  24apr2019   Wolves      35     1       3      3
# 8357  E0    2018  27apr2019   Wolves      36     0       3      2
# 8358  E0    2018  04may2019   Wolves      37     1       3      1
# 8359  E0    2018  12may2019   Wolves      38     0       0      0
#
#      team_opponent  points_opponent  goals_opponent  hometeam_uid  \
# 0        West Brom                0               0             1
# 1           Fulham                3               1            14
# 2        Newcastle                0               0             1
# 3        Blackburn                0               0             4
# 4           Bolton                0               1             6
# ...            ...              ...             ...           ...
# 8355      Brighton                1               0            36
# 8356       Arsenal                0               1            36
# 8357       Watford                0               1            32
# 8358        Fulham                0               0            36
# 8359     Liverpool                3               2            18
#
#       awayteam_uid
# 0               33
# 1                1
# 2               22
# 3                1
# 4                1
# ...            ...
# 8355             8
# 8356             1
# 8357            36
# 8358            14
# 8359            36
#
# [8360 rows x 13 columns]

# %%
epl_teams_games.loc[epl_teams_games["season"] == 2016]
# Out:
#      div  season       date      team  gameno  home  points  goals  \
# 304   E0    2016  14aug2016   Arsenal       1     1       0      3
# 305   E0    2016  20aug2016   Arsenal       2     0       1      0
# 306   E0    2016  27aug2016   Arsenal       3     0       3      3
# 307   E0    2016  10sep2016   Arsenal       4     1       3      2
# 308   E0    2016  17sep2016   Arsenal       5     0       3      4
# ...   ..     ...        ...       ...     ...   ...     ...    ...
# 7937  E0    2016  22apr2017  West Ham      34     1       1      0
# 7938  E0    2016  29apr2017  West Ham      35     0       1      0
# 7939  E0    2016  05may2017  West Ham      36     1       3      1
# 7940  E0    2016  14may2017  West Ham      37     1       0      0
# 7941  E0    2016  21may2017  West Ham      38     0       3      2
#
#      team_opponent  points_opponent  goals_opponent  hometeam_uid  \
# 304      Liverpool                3               4             1
# 305      Leicester                1               0            17
# 306        Watford                0               1            32
# 307    Southampton                0               1             1
# 308           Hull                0               1            16
# ...            ...              ...             ...           ...
# 7937       Everton                1               0            34
# 7938         Stoke                1               0            28
# 7939     Tottenham                0               0            34
# 7940     Liverpool                3               4            34
# 7941       Burnley                0               1             9
#
#       awayteam_uid
# 304             18
# 305              1
# 306              1
# 307             27
# 308              1
# ...            ...
# 7937            13
# 7938            34
# 7939            31
# 7940            18
# 7941            34
#
# [760 rows x 13 columns]

# %%
football_managers = pd.read_csv(data_in + "football_managers.csv")
football_managers
# Out:
#               manager_id         manager_name                     club  \
# 0          George Graham        George Graham                  Arsenal
# 1        Stewart Houston      Stewart Houston                  Arsenal
# 2            Bruce Rioch          Bruce Rioch                  Arsenal
# 3        Stewart Houston      Stewart Houston                  Arsenal
# 4               Pat Rice             Pat Rice                  Arsenal
# ..                   ...                  ...                      ...
# 390         Terry Burton         Terry Burton                Wimbledon
# 391           Dave Jones           Dave Jones  Wolverhampton Wanderers
# 392        Mick McCarthy        Mick McCarthy  Wolverhampton Wanderers
# 393         Terry Connor         Terry Connor  Wolverhampton Wanderers
# 394  Nuno Espírito Santo  Nuno Espírito Santo  Wolverhampton Wanderers
#
#      caretaker  date_from date_until                  nat league  \
# 0            0  14may1986  21feb1995             Scotland    EPL
# 1            1  22feb1995  08jun1995             Scotland    EPL
# 2            0  08jun1995  12aug1996             Scotland    EPL
# 3            1  12aug1996  13sep1996             Scotland    EPL
# 4            1  13sep1996  30sep1996     Northern Ireland    EPL
# ..         ...        ...        ...                  ...    ...
# 390          0  01may2000  25apr2002              England    EPL
# 391          0  03jan2001  11nov2004              England    EPL
# 392          0  05aug2006  14feb2012  Republic of Ireland    EPL
# 393          0  24feb2012  30jun2012              England    EPL
# 394          0  31may2017  01jul2019             Portugal    EPL
#
#      flag_inoffice
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ..             ...
# 390              0
# 391              0
# 392              0
# 393              0
# 394              1
#
# [395 rows x 9 columns]

# %%
# finally the merged file

football_managers_merged = pd.read_csv(
    data_in + "football_managers_workfile.csv"
).sort_values(["season", "team"])

# %% [markdown]
# ### 🕵️‍♀️ Bellonda's Logic Decoder
# **The Business Goal:** We are creating the fundamental metrics for "Managerial Success"—specifically **Longevity** (Games Managed) and **Performance** (Points Earned).
#
# **The Syntax Anatomy:**
# * `football_managers_merged` → **The Source** (Our raw game-level data)
# * `.groupby(["team", "..."])` → **The Buckets** (We are slicing the data to look at one specific manager's tenure at one specific team)
# * `.agg(...)` → **The Calculation** (Collapsing those game rows into a single summary number)
#     * `("div", "size")` → Count the rows to get **Total Games**.
#     * `("points", "sum")` → Add the values to get **Total Points**.
#
# > **💡 The Wisdom Check:**
# > We group by `team` AND `manager_id` because a manager might manage multiple teams, or return to the same team later. We must treat each tenure as a unique "case study" of success or failure.

# %%
games = football_managers_merged.groupby(["team", "manager_id", "manager_name"]).agg(
    manager_games=("div", "size")
)
points = football_managers_merged.groupby(["team", "manager_id", "manager_name"]).agg(
    manager_points=("points", "sum")
)

# %%
# default join is by indices which is multiindex group key this time --> No need to manually define keys
win_ratio = games.join(points)
win_ratio["manager_win_ratio"] = (
    win_ratio["manager_points"] / win_ratio["manager_games"]
)
win_ratio = win_ratio.sort_values(["manager_win_ratio"], ascending=False)

# %%
top_managers = win_ratio.sort_values(by=["manager_win_ratio"], ascending=False).head(11)
top_managers
# Out:
#                                           manager_games  manager_points  \
# team        manager_id manager_name
# Leicester   150        Michael Appleton               1               3
# Man City    175        Pep Guardiola                114             276
# Man United  12         Alex Ferguson                190             433
# Chelsea     17         Antonio Conte                 76             163
#             37         Carlo Ancelotti               76             157
# Man City    193        Roberto Mancini              134             276
# Liverpool   122        Jürgen Klopp                 144             296
# Man City    139        Manuel Pellegrini            114             231
# Chelsea     120        José Mourinho                 92             184
# Aston Villa 131        Kevin MacDonald                3               6
# West Ham    6          Alan Curbishley                3               6
#
#                                           manager_win_ratio
# team        manager_id manager_name
# Leicester   150        Michael Appleton            3.000000
# Man City    175        Pep Guardiola               2.421053
# Man United  12         Alex Ferguson               2.278947
# Chelsea     17         Antonio Conte               2.144737
#             37         Carlo Ancelotti             2.065789
# Man City    193        Roberto Mancini             2.059701
# Liverpool   122        Jürgen Klopp                2.055556
# Man City    139        Manuel Pellegrini           2.026316
# Chelsea     120        José Mourinho               2.000000
# Aston Villa 131        Kevin MacDonald             2.000000
# West Ham    6          Alan Curbishley             2.000000

# %% [markdown]
# ### Figure 2.1 The most successful managers

# %%
# denote caretakers
top_managers["manager_win_ratio0"] = [
    row["manager_win_ratio"] if row["manager_games"] < 18 else np.nan
    for index, row in top_managers.iterrows()
]
top_managers["manager_win_ratio1"] = [
    row["manager_win_ratio"] if row["manager_games"] > 18 else np.nan
    for index, row in top_managers.iterrows()
]

# %%
# denote caretakers
top_managers["fill"] = [
    1 if row["manager_games"] < 18 else 0 for index, row in top_managers.iterrows()
]

# %%
top_managers=top_managers.sort_values(["manager_win_ratio"]).reset_index()
top_managers
# Out:
#            team  manager_id       manager_name  manager_games  manager_points  \
# 0       Chelsea         120      José Mourinho             92             184
# 1   Aston Villa         131    Kevin MacDonald              3               6
# 2      West Ham           6    Alan Curbishley              3               6
# 3      Man City         139  Manuel Pellegrini            114             231
# 4     Liverpool         122       Jürgen Klopp            144             296
# 5      Man City         193    Roberto Mancini            134             276
# 6       Chelsea          37    Carlo Ancelotti             76             157
# 7       Chelsea          17      Antonio Conte             76             163
# 8    Man United          12      Alex Ferguson            190             433
# 9      Man City         175      Pep Guardiola            114             276
# 10    Leicester         150   Michael Appleton              1               3
#
#     manager_win_ratio  manager_win_ratio0  manager_win_ratio1  fill
# 0            2.000000                 NaN            2.000000     0
# 1            2.000000                 2.0                 NaN     1
# 2            2.000000                 2.0                 NaN     1
# 3            2.026316                 NaN            2.026316     0
# 4            2.055556                 NaN            2.055556     0
# 5            2.059701                 NaN            2.059701     0
# 6            2.065789                 NaN            2.065789     0
# 7            2.144737                 NaN            2.144737     0
# 8            2.278947                 NaN            2.278947     0
# 9            2.421053                 NaN            2.421053     0
# 10           3.000000                 3.0                 NaN     1

# %%
palette = [da.color[3] if x == 1 else da.color[0] for x in top_managers['fill']]
sns.barplot(
    x='manager_win_ratio',
    y='manager_name',
    data=top_managers,
    palette=palette,
    ci=None,
)
plt.xlabel("Average points per game")
plt.ylabel("Manager name")
plt.xlim(0, 3.1)
plt.xticks(ticks=np.arange(0, 3.1, 0.3))
plt.gca().invert_yaxis()

plt.show()

# %%
# In the book the last 3 managers are in a different order, but since all three's point average is 2.0, it is not a meaningful difference
